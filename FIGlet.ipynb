# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathyamrit/google-colab/blob/main/FIGlet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pyfiglet
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 67.3 kB/s eta 0:00:00
# ...

# %%
from pyfiglet import figlet_format

# %%
print(figlet_format(text="Hello", font="standard"))
# Out:
#  _   _      _ _
# | | | | ___| | | ___
# | |_| |/ _ \ | |/ _ \
# |  _  |  __/ | | (_) |
# |_| |_|\___|_|_|\___/

# %%
print(figlet_format(text="H e l l o", font="colossal"))
# Out:
# 888    888              888   888
# 888    888              888   888
# 888    888              888   888
# 8888888888    .d88b.    888   888    .d88b.
# 888    888   d8P  Y8b   888   888   d88""88b
# 888    888   88888888   888   888   888  888
# 888    888   Y8b.       888   888   Y88..88P
# 888    888    "Y8888    888   888    "Y88P"

# %%
f = open('output.txt','a')
text = figlet_format(text="Hello", font="standard")
f.write(text)
f.close()
